# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ff739ca3-30d6-4c89-ab15-bc79984cc7a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff739ca3-30d6-4c89-ab15-bc79984cc7a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Hypothesis Testing : 
# Null hypothesis (H0): Male-female buyer proportions are equal across all four regions.
# Alternative hypothesis (Ha): Male-female buyer proportions are not equal across all four regions.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
BuyersRatioData = pd.read_csv("BuyerRatio.csv")

# %%
BuyersRatioData.head()
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
BuyersRatioData.describe()
# Out:
#              East         West        North       South
# count    2.000000     2.000000     2.000000    2.000000
# mean   242.500000   832.500000   743.500000  410.000000
# std    272.236111   976.514465   866.205807  480.832611
# min     50.000000   142.000000   131.000000   70.000000
# 25%    146.250000   487.250000   437.250000  240.000000
# 50%    242.500000   832.500000   743.500000  410.000000
# 75%    338.750000  1177.750000  1049.750000  580.000000
# max    435.000000  1523.000000  1356.000000  750.000000

# %%
BuyersRatioData.dtypes
# Out:
# Observed Values    object
# East                int64
# West                int64
# North               int64
# South               int64
# dtype: object

# %%
BuyersRatioData.isnull().sum()
# Out:
# Observed Values    0
# East               0
# West               0
# North              0
# South              0
# dtype: int64

# %%
sns.boxplot(BuyersRatioData)
# Out:
# <Axes: >

# %%
BuyersRatioData.head()
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
from scipy.stats import chi2_contingency

# Create a list of the observed values for males and females in each region
observed_values = np.array([[50, 142, 131, 70], [435, 1523, 1356, 750]])

# Use the chi2_contingency function to calculate the test statistic and p-value
chi2_statistic, p_value, dof, expected_values = chi2_contingency(observed_values)

# Print the chi-square statistic and p-value
print('Chi-square statistic:', chi2_statistic)
print('p-value:', p_value)
# Out:
# Chi-square statistic: 1.595945538661058
# p-value: 0.6603094907091882

# %%
# The p-value (0.66) is greater than the significance level (0.05), 
# so we fail to reject the null hypothesis. 
# We can conclude that there is no evidence of an association between gender and region based on the data given.
